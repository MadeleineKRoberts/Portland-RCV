# %%
from etools import simulate_ensembles
import json
import random
import os

# %%
strength_1 = {"W": {"C": 1, "W": 1}, "C": {"W": 1, "C": 1}}
num_elections = 100

basic_start = simulate_ensembles(
    #ensemble=[random.choice(test_ensemble)],
    #election="PRES20",
    cohesion={"W": 0.7, "C": 0.8},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1
)

# %%
from gen_histogram import generate_histogram

generate_histogram(basic_start['bt'], 'bt')
generate_histogram(basic_start['pl'], 'pl')
generate_histogram(basic_start['cs'], 'cs')

# %%
more_w_cands = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.8},
    num_w=10,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(more_w_cands['bt'], 'bt')
generate_histogram(more_w_cands['pl'], 'pl')
generate_histogram(more_w_cands['cs'], 'cs')

# %%
more_poc_cands = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.8},
    num_w=3,
    num_c=10,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(more_poc_cands['bt'], 'bt')
generate_histogram(more_poc_cands['pl'], 'pl')
generate_histogram(more_poc_cands['cs'], 'cs')

# %%
less_w_cohesion = simulate_ensembles(
    cohesion={"W": 0.6, "C": 0.8},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(less_w_cohesion['bt'], 'bt')
generate_histogram(less_w_cohesion['pl'], 'pl')
generate_histogram(less_w_cohesion['cs'], 'cs')

# %%
less_w_cohesion_minus2 = simulate_ensembles(
    cohesion={"W": 0.5, "C": 0.8},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(less_w_cohesion_minus2['bt'], 'bt')
generate_histogram(less_w_cohesion_minus2['pl'], 'pl')
generate_histogram(less_w_cohesion_minus2['cs'], 'cs')

# %%
equal_cohesion = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.7},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(equal_cohesion['bt'], 'bt')
generate_histogram(equal_cohesion['pl'], 'pl')
generate_histogram(equal_cohesion['cs'], 'cs')

# %%
less_w_cohesion = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.6},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(less_w_cohesion['bt'], 'bt')
generate_histogram(less_w_cohesion['pl'], 'pl')
generate_histogram(less_w_cohesion['cs'], 'cs')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 less_w_cohesion = simulate_ensembles(
#       2     cohesion={"W": 0.7, "C": 0.6},
#       3     num_w=3,
#       4     num_c=3,
#       5     seats=3,
#       6     num_elections=num_elections,
#       7     alphas=strength_1,
#       8 )
#      10 generate_histogram(less_w_cohesion['bt'], 'bt')
#      11 generate_histogram(less_w_cohesion['pl'], 'pl')
#
# File ~/Downloads/initial_election_ tests/simulate/etools.py:99, in simulate_ensembles(cohesion, num_w, num_c, seats, num_elections, alphas, num_ballots, low_turnout, alternate_slate)
#      75 """
#      76 if model_name in ['cs', 'ac']:
#      77     generator = model.from_params(
#    (...)
#      90     )
#      91 """
#      92 generator = model.from_params(
#      93         slate_to_candidates=cand_slate,
#      94         bloc_voter_prop=blocs,
#      95         cohesion=cohesion,
#      96         alphas=alphas,
#      97     )
# ---> 99 ballots = generator.generate_profile(num_ballots)
#     101 results = STV(
#     102     ballots,
#     103     transfer=fractional_transfer,
#     104     seats=seats,
#     105     ballot_ties=False,
#     106 ).run_election()
#     107 num_winners = count_winners(results.winners(), "POC")
#
# File ~/Downloads/initial_election_ tests/simulate/utils.py:33, in BradleyTerry.generate_profile(cls, num_ballots)
#      31 ballot_lst = []
#      32 weights = {}
# ---> 33 for ranking in bradley_terry_dirichlet(
#      34     poc_share=cls.minority_share,
#      35     poc_support_for_poc_candidates=cls.poc_for_poc,
#      36     poc_support_for_white_candidates=cls.poc_for_w,
#      37     white_support_for_white_candidates=cls.w_for_w,
#      38     white_support_for_poc_candidates=cls.w_for_poc,
#      39     num_ballots=num_ballots,
#      40     num_poc_candidates=cls.num_poc,
#      41     num_white_candidates=cls.num_w,
#      42     concentrations=cls.alphas,
#      43     max_ballot_length=None,
#      44 ):
#      45     if tuple(ranking) not in weights:
#      46         weights[tuple(ranking)] = 0
#
# File ~/Downloads/initial_election_ tests/simulate/utils.py:109, in bradley_terry_dirichlet(poc_share, poc_support_for_poc_candidates, poc_support_for_white_candidates, white_support_for_white_candidates, white_support_for_poc_candidates, num_ballots, num_poc_candidates, num_white_candidates, concentrations, max_ballot_length)
#     107 ballots = []
#     108 numballots = num_ballots
# --> 109 ballots = paired_comparison_mcmc(
#     110     num_ballots,
#     111     {
#     112         0: {x: poc_support_vector[i] for i, x in enumerate(candidates)},
#     113         1: {x: white_support_vector[i] for i, x in enumerate(candidates)},
#     114     },
#     115     None,
#     116     candidates,
#     117     {0: poc_share, 1: 1 - poc_share},
#     118     [0, 1],
#     119     sample_interval=10,
#     120     verbose=False,
#     121 )
#     122 # winners
#     123 ballots = [b[:max_ballot_length] for b in ballots]
#
# File ~/Downloads/initial_election_ tests/simulate/utils.py:188, in paired_comparison_mcmc(num_ballots, mean_support_by_race, std_support_by_race, cand_list, vote_portion_by_race, race_list, seeds, sample_interval, verbose)
#     181 proposed_ballot[j1], proposed_ballot[j2] = (
#     182     proposed_ballot[j2],
#     183     proposed_ballot[j1],
#     184 )
#     186 # acceptance ratio: (note - symmetric proposal function!)
#     187 accept_ratio = min(
# --> 188     ballot_prob(proposed_ballot) / ballot_prob(start_ballot), 1
#     189 )
#     190 # accept or reject proposal
#     191 if random.random() < accept_ratio:
#
# File ~/Downloads/initial_election_ tests/simulate/utils.py:165, in paired_comparison_mcmc.<locals>.ballot_prob(ballot)
#     164 def ballot_prob(ballot):
# --> 165     pairs_list_ballot = list(itertools.combinations(ballot, 2))
#     166     paired_compare_trunc = {
#     167         k: paired_compare_dict[k] for k in pairs_list_ballot
#     168     }
#     169     ballot_prob = np.product(list(paired_compare_trunc.values()))
#
# KeyboardInterrupt:

# %%
less_w_cohesion_minus3 = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.5},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=strength_1,
)

generate_histogram(less_w_cohesion_minus3['bt'], 'bt')
generate_histogram(less_w_cohesion_minus3['pl'], 'pl')
generate_histogram(less_w_cohesion_minus3['cs'], 'cs')

# %%
lowered_strength = {"W": {"C": 0.5, "W": 1}, "C": {"W": 1, "C": 0.5}}
strength_lowered = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.8},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=lowered_strength
)

generate_histogram(strength_lowered['bt'], 'bt')
generate_histogram(strength_lowered['pl'], 'pl')
generate_histogram(strength_lowered['cs'], 'cs')

# %%
inc_strength = {"W": {"C": 2, "W": 1}, "C": {"W": 1, "C": 2}}

strength_inceased = simulate_ensembles(
    cohesion={"W": 0.7, "C": 0.8},
    num_w=3,
    num_c=3,
    seats=3,
    num_elections=num_elections,
    alphas=inc_strength
)

generate_histogram(strength_inceased['bt'], 'bt')
generate_histogram(strength_inceased['pl'], 'pl')
generate_histogram(strength_inceased['cs'], 'cs')
